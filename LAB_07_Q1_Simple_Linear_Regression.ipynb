# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51529/ADM-LAB/blob/main/LAB_07_Q1_Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

advertising = pd.DataFrame(pd.read_csv("/content/SLR_Salary_dataset.csv"))
advertising.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['YearsExperience'].plot(kind='hist', bins=20, title='YearsExperience')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Salary'].plot(kind='hist', bins=20, title='Salary')
# ...

# %%
advertising.shape
# Out:
# (30, 3)

# %%
advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
advertising.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['YearsExperience'].plot(kind='hist', bins=20, title='YearsExperience')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
advertising.isnull().sum()*100/advertising.shape[0]
# Out:
# Unnamed: 0         0.0
# YearsExperience    0.0
# Salary             0.0
# dtype: float64

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt2 = sns.boxplot(advertising['YearsExperience'], ax = axs[1])
plt3 = sns.boxplot(advertising['Salary'], ax = axs[2])
plt.tight_layout()

# %%
sns.boxplot(advertising['Salary'])
plt.show()

# %%
sns.pairplot(advertising, x_vars=['YearsExperience', 'Salary'], y_vars='Salary', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(advertising.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
#Simple Linear Regression
X = advertising['YearsExperience']
y = advertising['Salary']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
X_train.head()
# Out:
# 17     83089.0
# 22    101303.0
# 11     55795.0
# 4      39892.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
y_train.head()
# Out:
# 17     83089.0
# 22    101303.0
# 11     55795.0
# 4      39892.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
import statsmodels.api as sm

# %%
X_train_sm = sm.add_constant(X_train)

# Fit the resgression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()

# %%
lr.params
# Out:
# const              24230.767402
# YearsExperience     9731.203838
# dtype: float64

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     352.9
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           9.91e-14
# Time:                        04:29:02   Log-Likelihood:                -211.80
# No. Observations:                  21   AIC:                             427.6
# Df Residuals:                      19   BIC:                             429.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.423e+04   2921.388      8.294      0.000    1.81e+04    3.03e+04
# ...

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, 6.948 + 0.054*X_train, 'r')
plt.show()

# %%
y_train_pred = lr.predict(X_train_sm)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
fig.suptitle('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()
# Out:
# <ipython-input-35-2b44071c1f5f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(res, bins = 15)

# %%
plt.scatter(X_train,res)
plt.show()

# %%
# Add a constant to X_test
X_test_sm = sm.add_constant(X_test)

# Predict the y values corresponding to X_test_sm
y_pred = lr.predict(X_test_sm)

y_pred.head()
# Out:
# 9      61209.341988
# 26    117650.324249
# 28    125435.287320
# 13     65101.823523
# 5      53424.378917
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
#Looking at the RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 5505.479002176148

# %%
#Checking the R-squared on the test set
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# 0.9627668685473266

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, 6.948 + 0.054 * X_test, 'r')
plt.show()
